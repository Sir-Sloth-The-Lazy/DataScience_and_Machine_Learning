# %% [markdown]
# # String
# #### ✌🏻 Memory Architecture: Immutability
# Python strings are immutable. When you "change" a string, Python's memory manager creates a new object in the Private Heap.
#
# #### ✌🏻 Core Properties of Python Strings
# To master strings, you need to understand these four fundamental characteristics:
#
# | Property | Description | Example / Implication |
# |--------|-------------|----------------------|
# | Immutability | Once created, the content of a string cannot be changed in place. | `s[0] = 'a'` raises a `TypeError`. |
# | Ordered Sequence | Characters have a specific position (index) starting from 0. | `s[1]` accesses the second character. |
# | Iterable | You can loop through a string directly using a `for` loop. | `for char in "Python":` |
# | Indexable | Supports both positive (0 to n−1) and negative (−1 to −n) indexing. | `s[-1]` gives the last character. |
# | Slicable | Allows extracting substrings using the `[start:stop:step]` syntax. | `"Hello"[1:4]` returns `"ell"`. |
# | Homogeneous | Every element in a string is a character (string of length 1). There is no separate `char` type in Python. | `'a'` is of type `str`. |
# | Case Sensitive | Uppercase and lowercase characters are treated as different entities. | `"A" == "a"` is `False`. |
# | Unicode Based | Python 3 strings are stored as Unicode by default and can store emojis, Greek letters, etc. | `"π"`, `"😊"` |

# %% [markdown]
# Python's `str` class is packed with built-in methods. To make this digestible, I’ve categorized them by their primary purpose.
#
# Keep in mind that because strings are **immutable**, none of these functions modify the original string; they all return a **new** value.
#
# ### 1. Case Transformation Methods
#
# These methods change the visual "casing" of the text.
#
# | Method | Description | Example |
# | --- | --- | --- |
# | `.upper()` | Converts all characters to uppercase. | `"hi" -> "HI"` |
# | `.lower()` | Converts all characters to lowercase. | `"HI" -> "hi"` |
# | `.capitalize()` | Capitalizes only the first character. | `"python" -> "Python"` |
# | `.title()` | Capitalizes the first character of every word. | `"hello world" -> "Hello World"` |
# | `.swapcase()` | Swaps cases (lower to upper and vice-versa). | `"Py" -> "pY"` |
# | `.casefold()` | Aggressive lowercase for caseless matching. | `"ß" -> "ss"` |
#
# ---
#
# ### 2. Search and Inspection Methods
#
# Use these to find substrings or count occurrences.
#
# | Method | Description | Example |
# | --- | --- | --- |
# | `.find(sub)` | Returns the lowest index of `sub`. Returns `-1` if not found. | `"abc".find("b") -> 1` |
# | `.index(sub)` | Same as `.find()`, but raises `ValueError` if not found. | `"abc".index("z") -> Error` |
# | `.count(sub)` | Returns the number of non-overlapping occurrences. | `"banana".count("a") -> 3` |
# | `.startswith(prefix)` | Returns `True` if the string starts with the prefix. | `"Hello".startswith("H")` |
# | `.endswith(suffix)` | Returns `True` if the string ends with the suffix. | `"file.txt".endswith(".txt")` |
#
# ---
#
# ### 3. Classification / Boolean Methods
#
# These return `True` or `False` based on the content of the string.
#
# | Method | Returns `True` if... |
# | --- | --- |
# | `.isalpha()` | All characters are alphabetic (letters). |
# | `.isdigit()` | All characters are digits (numbers). |
# | `.isalnum()` | All characters are alphanumeric (letters or numbers). |
# | `.isspace()` | All characters are whitespace (spaces, tabs, newlines). |
# | `.islower()` | All cased characters are lowercase. |
# | `.isupper()` | All cased characters are uppercase. |
# | `.isprintable()` | The string doesn't contain hidden chars like `\n`. |
#
# ---
#
# ### 4. Splitting, Joining, and Cleaning
#
# Crucial for data processing and parsing.
#
# | Method | Description | Example |
# | --- | --- | --- |
# | `.split(sep)` | Splits string into a list based on a separator. | `"a,b,c".split(",") -> ['a', 'b', 'c']` |
# | `.join(iterable)` | Joins elements of an iterable into one string. | `"-".join(['a','b']) -> "a-b"` |
# | `.strip()` | Removes leading and trailing whitespace. | `"  hi  ".strip() -> "hi"` |
# | `.replace(old, new)` | Replaces occurrences of a substring. | `"apple".replace("a", "o") -> "opple"` |
# | `.lstrip()` / `.rstrip()` | Removes whitespace from only the Left or Right side. | `"  hi".lstrip() -> "hi"` |
#
# ---
#
# ### 5. Alignment and Formatting
#
# Used for pretty-printing and UI alignment.
#
# | Method | Description | Example |
# | --- | --- | --- |
# | `.center(width)` | Centers string within a specific width. | `"hi".center(6) -> "  hi  "` |
# | `.ljust(width)` | Left-aligns string. | `"hi".ljust(4) -> "hi  "` |
# | `.rjust(width)` | Right-aligns string. | `"hi".rjust(4) -> "  hi"` |
# | `.zfill(width)` | Pads the string with zeros on the left. | `"42".zfill(5) -> "00042"` |
# | `.format()` | Formats specified values in a string. | `"{0}".format("A")` |
#
# ### One Final Secret: `dir(str)`
#
# If you ever forget these, you can ask Python itself. Open a terminal and type:
#
# ```python
# print(dir(str))
#
# ```
#
# This will give you a list of every single attribute and method available to the string class.
#
# Would you like me to show you how to chain these methods together (e.g., `text.strip().lower().replace(...)`) to clean a piece of messy user input?

# %% [markdown]
# ## 🧠 THE MEGA PROBLEM: **Log Processing & User Analytics System**
#
# ### 📌 Problem Statement
#
# You are building a **Log Processing System** for a large-scale application (think Netflix / Amazon / Uber).
#
# The system receives **raw log strings** like this:
#
# ```
# "2026-01-30 10:45:23 | USER:John_Doe | ACTION:LOGIN | STATUS:Success | IP:192.168.1.1"
# ```
#
# Each log entry is a **string**.
#
# ---
#
# ## 🎯 SYSTEM REQUIREMENTS (What you must design)
#
# ### 1️⃣ **String Parsing (Core String Concepts)**
#
# You must extract:
#
# * Timestamp
# * Username
# * Action
# * Status
# * IP address
#
# 🔧 **String methods you’ll need**
#
# ```
# split(), strip(), find(), index(), replace(),
# startswith(), endswith(), lower(), upper()
# ```
#
# ---
#
# ### 2️⃣ **OOP Design (Mandatory)**
#
# Design **at least 3 classes**:
#
# #### ✅ `LogEntry`
#
# * Stores **one log**
# * Responsible for **parsing**
# * Immutable after creation (important!)
#
# #### ✅ `LogValidator`
#
# * Validates:
#
#   * IP format
#   * Status (`success`, `failure`)
#   * Action (`login`, `logout`, `purchase`)
#
# #### ✅ `LogAnalyzer`
#
# * Aggregates logs
# * Counts:
#
#   * logins per user
#   * failures per IP
#   * suspicious behavior
#
# ---
#
# ### 3️⃣ **System Design Concepts You Must Apply**
#
# | Concept               | Where it appears             |
# | --------------------- | ---------------------------- |
# | Immutability          | Strings + `LogEntry`         |
# | Single Responsibility | Each class has ONE job       |
# | Encapsulation         | Internal parsing hidden      |
# | Open/Closed Principle | Easy to add new log fields   |
# | Scalability           | Can process millions of logs |
# | Defensive Programming | Invalid logs handled safely  |
#
# ---
#
# ### 4️⃣ **Advanced String Operations (Required)**
#
# You **must** use:
#
# ```
# len(), count(), join(), format() / f-strings,
# isalnum(), isdigit(), isalpha(),
# encode(), decode(),
# casefold(), partition(), rpartition()
# ```
#
# Example constraints:
#
# * Username must be alphanumeric
# * IP must contain exactly 3 dots
# * Status comparison must be **case-insensitive**
# * Logs must support **Unicode usernames** (🔥 important)
#
# ---
#
# ### 5️⃣ **Security & Robustness (System Thinking)**
#
# Handle edge cases:
#
# * Extra spaces
# * Missing fields
# * Corrupted logs
# * Unicode attacks (`"Jøhn_Dœ"`)
#
# ---
#
# ## 🧪 INPUT SAMPLE
#
# ```
# logs = [
#  "2026-01-30 10:45:23 | USER:John_Doe | ACTION:LOGIN | STATUS:Success | IP:192.168.1.1",
#  "2026-01-30 10:46:10 | USER:alice99 | ACTION:LOGIN | STATUS:FAILURE | IP:192.168.1.1",
#  "2026-01-30 10:47:55 | USER:bob | ACTION:LOGOUT | STATUS:Success | IP:10.0.0.5"
# ]
# ```
#
# ---
#
# ## 🧩 YOUR FIRST TASK (DO NOT SKIP)
#
# ### 👉 Step 1: Thinking Question (Answer in words, not code)
#
# **Question:**
#
# > Which string methods would you use to **safely extract key-value pairs** from
# > `"USER:John_Doe | ACTION:LOGIN | STATUS:Success"`
# > and **why those methods instead of others?**
#
# 👉 Reply with:
#
# * Method names
# * 1–2 line justification each
#
# Once you answer this, we’ll:
#
# * Design the `LogEntry` class together
# * Then implement parsing
# * Then validation
# * Then analytics
# * Then optimize like a system designer 💪
#
# Your move 🎯
#
# I would use split('|') to separate each field since logs are delimiter-based.
# Then I would use strip() to clean whitespace.
# To extract key-value pairs safely, I would use partition(':') instead of find() because it avoids index errors and always returns predictable output.
# Finally, I would normalize keys and values using lower() or casefold() for case-insensitive processing.

# %% [markdown]
# Perfectly fine 👍 — this is *exactly* where learning happens.
#
# Let’s lock this in gently and clearly.
#
# ---
#
# ## 🧠 Why `partition(':')` is safer than `split(':')`
#
# ### 🔴 Problem with `split(':')`
#
# ```python
# "USER:John:Doe".split(':')
# # ['USER', 'John', 'Doe']
# ```
#
# * You **don’t know how many parts** you’ll get
# * Breaks if `:` appears inside the value
# * Leads to `IndexError` or wrong parsing
#
# ---
#
# ### ✅ Why `partition(':')` is safer
#
# ```python
# "USER:John:Doe".partition(':')
# # ('USER', ':', 'John:Doe')
# ```
#
# ✔ Always returns **exactly 3 elements**
# ✔ Splits on the **first occurrence only**
# ✔ No exceptions → **predictable behavior**
# ✔ Perfect for **system design & production logs**
#
# ---
#
# ### 📌 One-line answer you should remember (exam/interview)
#
# > `partition()` is safer because it always returns a fixed-size result and avoids errors when delimiters appear inside values.
#
# 🧠 **Mnemonic**:
# **Partition = Predictable**
#
# ---
#
# ## 🔒 Concept Check (very quick)
#
# 👉 Tell me in **one sentence**:
#
# * Why strings being **immutable** is useful for a system like log processing?
#
#
# ## ✅ Refined Answer (Perfect Form)
#
# > Strings being immutable ensures that once a log entry is created, it cannot be modified accidentally or maliciously. Any change creates a new string, which keeps the original log data safe, reliable, and audit-friendly.
#
# ### 🔑 Why this matters in systems:
#
# * **Data integrity** → logs must never change
# * **Thread safety** → multiple components can read safely
# * **Debugging & audits** → original data preserved
#
# 🧠 **Mnemonic**:
# **Immutable = Trustworthy data**
#
# ---
#
# ## 🚀 NEXT STEP: OOP + Strings (Now it gets fun)
#
# ### 🎯 Goal
#
# Design the **`LogEntry` class** that:
#
# * Accepts a raw log string
# * Parses it using string methods
# * Is **immutable after creation**
# * Hides parsing logic (encapsulation)
#
# ⚠️ I will NOT write the code for you.
# You will design it step by step.
#
# ---
#
# ## 🧩 Step 1 — Class Design (NO CODE YET)
#
# Answer this in **bullet points**:
#
# 1️⃣ What **attributes** should a `LogEntry` object store?
#
#
# 2️⃣ Which attributes should be **private** and why?
#
# 3️⃣ How will you **prevent modification** after creation?
#
# # Python Strings + OOP + System Design (Interview Notes)
#
# These notes summarize our discussion on **Python strings**, **OOP principles**, and **system design thinking**, using a **log processing system** as the core example. Use this as a quick revision guide before interviews.
#
# ---
#
# ## 1. Core Python String Concepts
#
# ### 🔒 Immutability
#
# * Strings in Python are **immutable**.
# * Any modification creates a **new string**.
# * Original data always remains unchanged.
#
# **Why important in systems:**
#
# * Ensures **data integrity** (logs must not change)
# * Safe for **multi-threaded systems**
# * Reliable for **auditing and debugging**
#
# **Interview line:**
#
# > Immutable strings make log data trustworthy and thread-safe.
#
# ---
#
# ### 📌 Ordered & Indexable
#
# * Strings are ordered sequences (index starts at 0)
# * Support positive and negative indexing
#
# Examples:
#
# * `s[0]` → first character
# * `s[-1]` → last character
#
# ---
#
# ### 🔁 Iterable
#
# * Strings can be iterated character by character
#
# ```python
# for ch in "Python":
#     pass
# ```
#
# ---
#
# ### ✂️ Slicing
#
# * Syntax: `[start:stop:step]`
# * Used for extracting substrings
#
# Example:
#
# * `"Hello"[1:4] → "ell"`
#
# ---
#
# ### 🔤 Homogeneous & Case Sensitive
#
# * Every element is a string of length 1
# * No separate `char` type
# * `'A' != 'a'`
#
# ---
#
# ### 🌍 Unicode-Based
#
# * Python 3 strings are Unicode by default
# * Supports emojis, Greek letters, accented characters
#
# Example:
#
# * `"π"`, `"😊"`, `"Jøhn"`
#
# ---
#
# ## 2. String Methods (Production-Relevant)
#
# ### 🔹 Parsing & Cleaning
#
# * `split()` → break log into fields
# * `strip()` → remove extra spaces
# * `partition()` → safe key-value separation
#
# **Why `partition()` > `split(':')`:**
#
# * Always returns **exactly 3 parts**
# * Splits only on first occurrence
# * Predictable, fail-safe
#
# **Mnemonic:** Partition = Predictable
#
# ---
#
# ### 🔹 Searching
#
# * `find()` → returns index or `-1`
# * `index()` → raises error if not found
#
# Used carefully in production systems.
#
# ---
#
# ### 🔹 Normalization
#
# * `lower()` / `casefold()` → case-insensitive comparison
# * `replace()` → sanitization
#
# ---
#
# ### 🔹 Validation
#
# * `isalnum()` → username validation
# * `isdigit()` → numeric checks
# * `count()` → IP validation (`.` count)
# * `len()` → length constraints
#
# ---
#
# ### 🔹 Formatting & Joining
#
# * `join()` → combine strings efficiently
# * `f-strings` / `format()` → readable logging
#
# ---
#
# ## 3. OOP Design Using Log Processing Example
#
# ### 🎯 Log Example
#
# ```
# 2026-01-30 10:45:23 | USER:John_Doe | ACTION:LOGIN | STATUS:Success | IP:192.168.1.1
# ```
#
# ---
#
# ### 🧱 Core Classes
#
# #### 1️⃣ `LogEntry`
#
# **Responsibility:**
#
# * Store **one immutable log**
# * Parse raw string
#
# **Attributes:**
#
# * `timestamp`
# * `username`
# * `action`
# * `status`
# * `ip_address`
# * (optional) `raw_log`
#
# All attributes are **private**.
#
# ---
#
# #### 2️⃣ `LogValidator`
#
# **Responsibility:**
#
# * Validate fields
#
# Examples:
#
# * Username → alphanumeric
# * IP → exactly 3 dots
# * Status → success / failure
# * Action → login / logout / purchase
#
# ---
#
# #### 3️⃣ `LogAnalyzer`
#
# **Responsibility:**
#
# * Aggregate logs
# * Count logins per user
# * Detect suspicious IPs
#
# ---
#
# ## 4. Encapsulation & Immutability in OOP
#
# ### 🔐 Private Attributes
#
# * All attributes should be private by default
# * Protects internal state
# * Allows internal changes without breaking users
#
# **Rule:** Public behavior, private data
#
# ---
#
# ### 🧊 Enforcing Immutability
#
# * Initialize values **once** in constructor
# * No setter methods
# * Expose data via **read-only properties** (`@property`)
# * Rely on string immutability
#
# **Interview line:**
#
# > Immutability is enforced using private attributes, no setters, and read-only properties.
#
# ---
#
# ## 5. System Design Principles Applied
#
# ### ✅ Fail-Fast Principle
#
# * Parse and validate **immediately** in constructor
# * Invalid logs rejected early
#
# **Why:**
#
# * Easier debugging
# * Prevents bad data propagation
#
# ---
#
# ### ✅ Strong Invariants
#
# * If a `LogEntry` object exists → it is valid
# * Downstream systems can trust it
#
# ---
#
# ### ✅ Single Responsibility Principle
#
# * Each class does **one thing well**
#
# ---
#
# ### ✅ Scalability
#
# * String parsing is O(n)
# * No repeated validation
# * Ready for millions of logs
#
# ---
#
# ## 6. High-Value Interview One-Liners
#
# * *"Partition is safer than split because it guarantees predictable output."*
# * *"Immutable strings ensure data integrity in logging systems."*
# * *"Fail fast keeps systems reliable and debuggable."*
# * *"Encapsulation protects invariants and enables change."*
#
# ---
#
# ## 7. Mental Model to Remember
#
# ```
# Strings → Immutable data
# Parsing → Predictable methods
# Private state → Encapsulation
# No setters → Immutability
# Early validation → Fail fast
# ```
#
# ---
#
# ### ✅ You now understand:
#
# * Python string internals
# * Production-safe string parsing
# * OOP design with immutability
# * System-design thinking using strings
#
# Use this as a **revision sheet before interviews**.

# %%
class LogEntry:
    def __init__(self, raw_log: str):
        self._raw_log = raw_log

        parts = raw_log.split('|')
        self._timestamp = parts[0].strip()

        self._username = None
        self._action = None
        self._status = None
        self._ip_address = None

        for part in parts[1:]:
            key, _, value = part.strip().partition(':')
            key = key.casefold()

            if key == 'user':
                self._username = value
            elif key == 'action':
                self._action = value
            elif key == 'status':
                self._status = value
            elif key == 'ip':
                self._ip_address = value

        # 🔥 Fail-fast validation
        self._validate()

    def _validate(self):
        # username validation
        if not self._username:
            raise ValueError("Missing username")

        if not self._username.replace('_', '').isalnum():
            raise ValueError("Invalid username format")

        # action validation
        if not self._action:
            raise ValueError("Missing action")

        # status validation
        if not self._status:
            raise ValueError("Missing status")

        if self._status.casefold() not in ("success", "failure"):
            raise ValueError("Invalid status value")

        # IP validation
        if not self._ip_address:
            raise ValueError("Missing IP address")

        if self._ip_address.count('.') != 3:
            raise ValueError("Invalid IP address format")

    # 🔒 Read-only properties

    @property
    def username(self):
        return self._username

    @property
    def action(self):
        return self._action

    @property
    def status(self):
        return self._status

    @property
    def ip_address(self):
        return self._ip_address

    @property
    def timestamp(self):
        return self._timestamp

# %% [markdown]
# LogValidator -- Rule based validation

# %%
class LogValidator:
    VALID_ACTIONS = {"login" , "logout" , "purchase"}
    VALID_STATUS = {"success" , "failure"}
    
    @staticmethod
    def validate(entry: LogEntry):
        if entry.action.casefold() not in LogValidator.VALID_ACTIONS:
            raise ValueError("Invalid action")
        
        if entry.status.casefold() not in LogValidator.VALID_STATUS:
            raise ValueError("Invalid status")
        
        if entry.ip_address.count('.') != 3:
            raise ValueError("Invalid IP address")

# %% [markdown]
# LogAnalyzer — aggregation & detection

# %%
class LogAnalyzer :
    def __init__(self):
        self._logins_per_user = {}
        self._failure_per_ip = {}

    def process(self, entry: LogEntry):
        if entry.action.casefold() == "login":
            self._logins_per_user[entry.username] = (
                self._logins_per_user.get(entry.username, 0) + 1
        )

        if entry.status.casefold() == "failure":
            self._failure_per_ip[entry.ip_address] = (
                self._failure_per_ip.get(entry.ip_address , 0) + 1
           )
    def suspicious(self, threshold=3):
        return[
            ip for ip, count in self._failure_per_ip.items() if count >= threshold
        ]

# %%
logs = [
    "2026-01-30 10:45:23 | USER:John_Doe | ACTION:LOGIN | STATUS:Success | IP:192.168.1.1",
    "2026-01-30 10:46:10 | USER:alice99 | ACTION:LOGIN | STATUS:FAILURE | IP:192.168.1.1",
    "2026-01-30 10:47:55 | USER:bob | ACTION:LOGOUT | STATUS:Success | IP:10.0.0.5",
    "2026-01-30 10:48:12 | USER:alice99 | ACTION:LOGIN | STATUS:FAILURE | IP:192.168.1.1",
    "2026-01-30 10:49:01 | USER:alice99 | ACTION:LOGIN | STATUS:FAILURE | IP:192.168.1.1",
]

# %%
analyzer = LogAnalyzer()
for raw_logs in logs:
    try:
        entry = LogEntry(raw_logs)
        LogValidator.validate(entry)
        analyzer.process(entry)
    except ValueError as e:
        print(f"Invalid log entry: {e}")

print("Suspicious IPs:", analyzer.suspicious())
# Out:
# Suspicious IPs: ['192.168.1.1']

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Common Index in Strings
#
# ✅ How do you find the first character in the string ?
# Answer : `s[0]`
#
# ✅ How do you find the last character in the string ?
# Answer : `s[-1]` or `s[len(s)-1]`
#
# if we try `s[len(s)]` it will throw an error
#
#
# if we have a word like "Good Morning" ans we want to remove "Good" from it we can use word = "Good"

# %%
sentence = "Good Morning"
word = "Good"

print(sentence[len(word):])
# Out:
#  Morning

# %% [markdown]
# ### `in` and `not in` operators (Test Membership)
#
# The `in` operator is used to check if a value is a subsequence of another sequence. Returns `True` if the value is a subsequence of the sequence, and `False` otherwise.

# %%
word_1 ="William"
word_2 ="Williamstown"

print(word_1 in word_2)
print(word_2 in word_1)
print("W" in word_1)
print("W" in word_2)
print("" in word_1)
print("" in word_2)
print("w" in word_1) # captialization matters
print("liams" in "WiLLiams")
# Out:
# True
# False
# True
# True
# True
# True
# False
# False

# %% [markdown]
# # Comparing strings

# %%
"abc" < "abcd"
# Out:
# True

# %%
print("ABC" < "abc") # ascii value of A = 65 and a = 97
# Out:
# True

# %%
print("Paul Jones" < "Paul Smith")
# Out:
# True

# %% [markdown]
# ## Slicing
# slicing syntax is [start:stop:step] where `stop` = 1+ index of the last element we want to include. Just like in the range function : the `end` index is not included
# ![image.png](attachment:image.png)

# %%
s = "Python"
print(s[0:4])
print(s[:4]) # by default start index is 0
print(s[2:]) # by default end index is the last index
print(s[2:len(s)]) # same as s[2:]
print(s[2::2]) # step size is 2
print(s[::-1]) # reverse the string
print(s[1:-2]) # negative index 

'''
Starting index is included but ending index is not included
'''
# Out:
# Pyth
# Pyth
# thon
# thon
# to
# nohtyP
# yth
# '\nStarting index is included but ending index is not included\n'

# %%
'''
What will be printed by the given program?
'''

month = "January"
day = 10 
output_string = ""
# control flow 1 starts
if day <= 10 :
    output_string += "Early "
# control flow 1 ends    
if day >= 20 :
    output_string += "Late " # new if statement marks the starting of control flow 2
else :
    output_string += "Mid " # control flow 2 ends but starting of new control flow will be decided by the next if statement

output_string += month
print(output_string)
# Out:
# Early Mid January

# %% [markdown]
# ####  Gate output question
# ![image.png](attachment:image.png)

# %%
a = [6,5,4,3,2,1,0]
b = "success"
c = b[a[-3]] + b[::4] # output : cse => slicing will include the starting index and then jump to step + start index which is 4
d = a[1] * a[2] * a[-3] * a[4 // 2]
x = str(c) + str(d)
print(x)
# Out:
# cse160

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
For these type of questions we need to do a rough indexing positive and negative both
0 1 2 3 4 5 6 7
W e h r w e i n
-8 -7 -6 -5 -4 -3 -2 -1
'''
last_name = "Wehrwein"
print(last_name[7:8])
print(last_name[6:-1])
print(last_name[-3:])
print(last_name[-2:8]) # answer
# Out:
# n
# i
# ein
# Answer :  in

# %%
place = "Delhi"
print(place[0:len(place):2])
print(place[::2]) # same as above
print(place[4:0:-1])
print(place[4::-1]) # same as place[::-1]
# Out:
# Dli
# Dli
# ihle
# ihleD

# %% [markdown]
# Defualt values of `start` and `stop` depend on the sign of `step`
#
# s[:3:1] &rarr; default start value is 0 \
# s[2::1] &rarr; default end value is len(s)
#
# #### If step is negative
# s[5::-1] &rarr; default value of stop is whole string including from right to left \
# s[:3:-1] &rarr; default value of start is len(s)

# %%
s = "Hello World"
s[6::-1] # stop = whole string till the end from right to left
# Out:
# 'W olleH'

# %%
s[6:0:-1] # stop != 0 because the output is different from above
# Out:
# 'W olle'

# %%
s[:3:-1] # start = len(s)
# Out:
# 'dlroW o'

# %%
s[len(s) : 3: -1] # same as above
# Out:
# 'dlroW o'

# %%
sequence = "Hello"
print(sequence[-1:0:-1])
print(sequence[-1::1])
print(sequence[-1:0:1]) # does not print anything
print(sequence[-1:-6:-1]) 
print(sequence[::-2])# start and end are always interpreted "backwards" when using a negative step
place = "Williamstown"
print(place[::-2])
# Out:
# olle
# o
#
# olleH
# olH
# nosali

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Stripping Whitespace

# %%
s = "   a b c    "
s.lstrip()
# Out:
# 'a b c    '

# %%
s.rstrip()
# Out:
# '   a b c'

# %%
s.strip() # any of this cannot remove space from between the string
# Out:
# 'a b c'

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# Strings are immutable this means that when we pass a string in a function we are guaranteed by python that the original string will not be changed. However the changes will be reflected using a new string

# %% [markdown]
# # What happens when we reassgin the same variable with a different value ?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * when we use the methods like .upper() or any method that appear to change the string , it is actually creating a new string and returing that address (Question : methods vs functions)
