# %% [markdown]
# # Python Basics

# %%
1 + 1
# Out:
# 2

# %%
# better way is
print(1+1)
# Out:
# 2

# %% [markdown]
# # INPUT

# %%
val = int(input("Enter a number: "))
print("You entered:", val)
# Out:
# You entered: 32
